# %%
library(DESeq2)
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ dplyr::count()      masks matrixStats::count()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::slice()      masks IRanges::slice()

# %%
#load count output tables from featurecounts after STAR 

#mouseexp4 counts 
Ca_counts <- read.table("/data/haley/RNAseq/mouseexp4/featurecounts/C_alb_mRNA_STAR_counts.txt", header= TRUE)
#delete extraneous rows 
Ca_counts <- select(Ca_counts, -c(2:6))

#mouseexp3/2 and invitro counts 
Cacounts2 <- read.table("/data/haley/RNAseq/mouseexp3/featurecounts2/C_alb_mRNA_STAR_counts.txt", header= TRUE)
Cacounts2 <- select(Cacounts2, -c(2:6))

#combine all counts into one table 
Cacounts3 <- merge(Ca_counts, Cacounts2,  by='Geneid')

#copy colnames from output and paste into correct space in the metadata file used below 
colnames(Cacounts3)
# Out:
#  [1] "Geneid"
#  [2] "...mouseexp2.Ca_starout_Aallele.Sample02_13AM2_v2_S18_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [3] "...mouseexp2.Ca_starout_Aallele.Sample04_13CF2_v2_S20_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [4] "...mouseexp2.Ca_starout_Aallele.Sample08_21CF4_S8_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [5] "...mouseexp2.Ca_starout_Aallele.Sample07_21CF3_S7_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [6] "...mouseexp2.Ca_starout_Aallele.Sample01_13AM1_v2_S17_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [7] "...mouseexp2.Ca_starout_Aallele.Sample05_21CF1_S5_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [8] "...mouseexp2.Ca_starout_Aallele.Sample04_21BM4_S4_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
#  [9] "...mouseexp2.Ca_starout_Aallele.Sample03_21AM3_S3_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [10] "...mouseexp2.Ca_starout_Aallele.Sample01_21AM1_S1_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [11] "...mouseexp2.Ca_starout_Aallele.Sample05_13CF3_v2_S21_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [12] "...mouseexp2.Ca_starout_Aallele.Sample02_21AM2_S2_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [13] "...mouseexp2.Ca_starout_Aallele.Sample03_13BM3_v2_S19_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [14] "...mouseexp2.Ca_starout_Aallele.Sample06_21CF2_S6_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [15] "...mouseexp3.starout4.mouse.CaEf_starout.Sample18_23M3_gnoto_Candida.albicans_Enterococcus.faecalis_S18_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [16] "...mouseexp3.starout4.mouse.CaEf_starout.Sample21_23F2_gnoto_Candida.albicans_Enterococcus.faecalis_S21_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [17] "...mouseexp3.starout4.mouse.CaEf_starout.Sample23_23F4_gnoto_Candida.albicans_Enterococcus.faecalis_S23_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [18] "...mouseexp3.starout4.mouse.CaEf_starout.Sample22_23F3_gnoto_Candida.albicans_Enterococcus.faecalis_S22_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [19] "...mouseexp3.starout4.mouse.CaEf_starout.Sample17_23M2_gnoto_Candida.albicans_Enterococcus.faecalis_S17_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [20] "...mouseexp3.starout4.mouse.CaEf_starout.Sample16_23M1_gnoto_Candida.albicans_Enterococcus.faecalis_S16_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [21] "...mouseexp3.starout4.mouse.CaEf_starout.Sample19_23M4_gnoto_Candida.albicans_Enterococcus.faecalis_S19_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [22] "...mouseexp3.starout4.mouse.CaEf_starout.Sample20_23F1_gnoto_Candida.albicans_Enterococcus.faecalis_S20_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [23] "..starout.mouse.CaEf_starout.Sample03_gnoto_CaEfF1_S3_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [24] "..starout.mouse.CaEf_starout.Sample19_gnoto_CaEfM3_polyA_S19_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [25] "..starout.mouse.CaEf_starout.Sample06_gnoto_CaEfM2_S6_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [26] "..starout.mouse.CaEf_starout.Sample02_gnoto_CaEfM5_S2_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [27] "..starout.mouse.CaEf_starout.Sample18_gnoto_CaEfM2_polyA_S18_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [28] "..starout.mouse.CaEf_starout.Sample04_gnoto_CaEfF3_S4_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [29] "..starout.mouse.CaEf_starout.Sample20_gnoto_CaEfM6_polyA_S20_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [30] "..starout.mouse.CaEf_starout.Sample08_gnoto_CaEfM6_S8_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [31] "..starout.mouse.CaEf_starout.Sample01_gnoto_CaEfM4_S1_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [32] "..starout.mouse.CaEf_starout.Sample07_gnoto_CaEfM3_S7_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [33] "..starout.mouse.CaEf_starout.Sample05_gnoto_CaEfM1_S5_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [34] "..starout.mouse.CaEf_starout.Sample17_gnoto_CaEfF3_polyA_S17_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [35] "..starout4.invitro.Ca_starout.Sample31_Candida.albicans_hypoxic_3_S31_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [36] "..starout4.invitro.Ca_starout.Sample24_Candida.albicans_hypoxic_2_S24_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [37] "..starout4.invitro.Ca_starout.Sample38_Candida.albicans_hypoxic_3_S37_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [38] "..starout4.invitro.CaEf_starout.Sample39_Candida.albicans_Enterococcus.faecalis_hypoxic_3_S38_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [39] "..starout4.invitro.CaEf_starout.Sample25_Candida.albicans_Enterococcus.faecalis_hypoxic_2_S25_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"
# [40] "..starout4.invitro.CaEf_starout.Sample32_Candida.albicans_Enterococcus.faecalis_hypoxic_3_S32_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam"

# %%
#load sample metadata table with experimental information. Edit table as necessary in excel (save as .txt though) 

#load table for mouse samples
Ca_samples <- read.table("mouseexp4_Ca-metadata.txt", header= TRUE) 
#load table for invitro samples 
Ca_samples2 <- read.table("/data/haley/RNAseq/mouseexp3/DESeq_AfterSTAR/mouseexp3_Ca-metadata.txt", header= TRUE)
Ca_samples2 <- Ca_samples2[22:27,] #get rid of extraneous sample rows 

#combine rows of in vitro and mouse samples
Ca_samples3 <- rbind(Ca_samples,Ca_samples2)
Ca_samples4 <- Ca_samples3[-c(30:33),] # get rid of PolyA samples
rownames(Ca_samples4)<-NULL
Ca_samples4

#Grab rows (and order) of sample metadata
col.order_Ca <- c("Geneid", Ca_samples4$filename)
Ca_counts4 <- Cacounts3[,col.order_Ca] #apply order to columns of counts table, also gets rid of the polyA samples as it is both a selection and orders the columns according to that of the sample table (doesn't have polyA) 

#superimpose shortened sample name over filepath name in counts table (will become the name of sample in later analysis) 
all(colnames(select(Ca_counts4, -c(1))) == Ca_samples4$filename, na.rm=TRUE)
colnames(Ca_counts4) <- c('Geneid',paste0(Ca_samples4$samplename))
rownames(Ca_counts4) <- Ca_counts4[,1]
Ca_counts4[,1] <- NULL


# write.csv(Ca_counts4, "Cacounts4.csv")
# write.csv(Ca_samples3, "Ca_samples3.csv")
# Out:
#    samplename sample     condition    species1         species2
# 1  mCa_13AM1  mCa_13AM1  mouse_Ca     Candida_albicans null
# 2  mCa_13AM2  mCa_13AM2  mouse_Ca     Candida_albicans null
# 3  mCa_13BM3  mCa_13BM3  mouse_Ca     Candida_albicans null
# 4  mCa_13CF2  mCa_13CF2  mouse_Ca     Candida_albicans null
# 5  mCa_13CF3  mCa_13CF3  mouse_Ca     Candida_albicans null
# 6  mCa_21AM1  mCa_21AM1  mouse_Ca     Candida_albicans null
# 7  mCa_21AM2  mCa_21AM2  mouse_Ca     Candida_albicans null
# 8  mCa_21AM3  mCa_21AM3  mouse_Ca     Candida_albicans null
# 9  mCa_21BM4  mCa_21BM4  mouse_Ca     Candida_albicans null
# 10 mCa_21CF1  mCa_21CF1  mouse_Ca     Candida_albicans null
# 11 mCa_21CF2  mCa_21CF2  mouse_Ca     Candida_albicans null
# 12 mCa_21CF3  mCa_21CF3  mouse_Ca     Candida_albicans null
# 13 mCa_21CF4  mCa_21CF4  mouse_Ca     Candida_albicans null
# 14 mCaEf_23M1 mCaEf_23M1 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 15 mCaEf_23M2 mCaEf_23M2 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 16 mCaEf_23M3 mCaEf_23M3 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 17 mCaEf_23M4 mCaEf_23M4 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 18 mCaEf_23F1 mCaEf_23F1 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 19 mCaEf_23F2 mCaEf_23F2 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 20 mCaEf_23F3 mCaEf_23F3 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 21 mCaEf_23F4 mCaEf_23F4 mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 22 mCaEf2_M4  mCaEf2_M4  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 23 mCaEf2_M5  mCaEf2_M5  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 24 mCaEf2_F1  mCaEf2_F1  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 25 mCaEf2_F3  mCaEf2_F3  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 26 mCaEf2_M1  mCaEf2_M1  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 27 mCaEf2_M2  mCaEf2_M2  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 28 mCaEf2_M3  mCaEf2_M3  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 29 mCaEf2_M6  mCaEf2_M6  mouse_CaEf   Candida_albicans Enterococcus_faecalis
# 30 Ca1        Ca1        invitro_Ca   Candida_albicans null
# 31 Ca2        Ca2        invitro_Ca   Candida_albicans null
# 32 Ca3        Ca3        invitro_Ca   Candida_albicans null
# 33 CaEf1      CaEf1      invitro_CaEf Candida_albicans Enterococcus_faecalis
# 34 CaEf2      CaEf2      invitro_CaEf Candida_albicans Enterococcus_faecalis
# 35 CaEf3      CaEf3      invitro_CaEf Candida_albicans Enterococcus_faecalis
#    environment
# 1  mouse
# 2  mouse
# 3  mouse
# 4  mouse
# 5  mouse
# 6  mouse
# 7  mouse
# 8  mouse
# 9  mouse
# 10 mouse
# 11 mouse
# 12 mouse
# 13 mouse
# 14 mouse
# 15 mouse
# 16 mouse
# 17 mouse
# 18 mouse
# 19 mouse
# 20 mouse
# 21 mouse
# 22 mouse
# 23 mouse
# 24 mouse
# 25 mouse
# 26 mouse
# 27 mouse
# 28 mouse
# 29 mouse
# 30 invitro
# 31 invitro
# 32 invitro
# 33 invitro
# 34 invitro
# 35 invitro
#    filename
# 1  ...mouseexp2.Ca_starout_Aallele.Sample01_13AM1_v2_S17_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
# 2  ...mouseexp2.Ca_starout_Aallele.Sample02_13AM2_v2_S18_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
# 3  ...mouseexp2.Ca_starout_Aallele.Sample03_13BM3_v2_S19_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
# 4  ...mouseexp2.Ca_starout_Aallele.Sample04_13CF2_v2_S20_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
# 5  ...mouseexp2.Ca_starout_Aallele.Sample05_13CF3_v2_S21_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
# 6  ...mouseexp2.Ca_starout_Aallele.Sample01_21AM1_S1_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
# 7  ...mouseexp2.Ca_starout_Aallele.Sample02_21AM2_S2_R1_001_fastp_output.fastq.gz_Aligned.sortedByCoord.out.bam
#